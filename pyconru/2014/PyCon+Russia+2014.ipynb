# %%
import os

import dateparser
import parsel
import yaml

start = 'pages/program/content'
talks = []
for cnt, talk in enumerate(os.listdir(start), start=1):
    #print(cnt, talk)
    talk_data = {'slug': talk}
    try:
        with open(start + '/' + talk + '/content.en.yaml') as f:
            talk_data.update({'en': yaml.load(f)})
    except:
        pass
    try:
        with open(start + '/' + talk + '/content.ru.yaml') as f:
            talk_data.update({'ru': yaml.load(f)})
    except:
        pass
    try:
        with open(start + '/' + talk + '/media.md') as f:
            selector = parsel.Selector(f.read())
            talk_data['media'] = selector.xpath('//iframe/@src').extract_first()
    except:
        pass
    talks.append(talk_data)

# %%
import re
from urllib.parse import urlparse

for t in talks:
    #print(t['en']["speaker"], t['en'].get('title', t['ru'].get('title')), t.get('media'))
    p = urlparse(t.get('media', '')).path
    try:
        d = re.search('/embed/(?P<video_id>.+)', p).groupdict()
        t['youtube_url'] = 'https://www.youtube.com/watch?v={}'.format(d['video_id'])
    except:
        continue

# %%
# ---- schedule
schedule = {}
mapping = {
    'day1': dateparser.parse('2014-06-02'),
    'day2': dateparser.parse('2013-06-03'),
}
try:
    with open('pages/program/schedule/data.ru.yaml') as f:
        d = yaml.load(f)
        for day, data in d.items():
            dt = mapping[day]
            for _, t in data.items():
                for talk in t:
                    slug = talk.get('slug')
                    if slug:
                        schedule[slug.lower()] = {
                            'datetime': dt,
                            'title': talk.get('talk'),
                            'speaker': talk.get('speaker'),
                        }
except:
    print(talk)
    raise

# %%
set(schedule.keys()) - set(t['slug'].lower() for t in talks)
# Out:
# {'lightning-talks-1', 'lightning-talks-2'}

# %%
schedule, len(schedule)
# Out:
# ({'asyncio': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': 'Андрей Светлов, LevelUp',
#    'title': 'Как писать для asyncio. Советы от разработчика библиотеки.'},
#   'autoscaling-on-the-cloud': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Simone Soldateschi',
#    'title': 'Auto scaling on the Cloud the right way'},
#   'bdd_in_python': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': 'Кирилл Борисов, БАРС Груп',
#    'title': 'Behavior Driven Development in Python'},
#   'data_analysis': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Роман Иманкулов, Todoist',
#    'title': 'Python для анализа данных'},
#   'explore-your-data': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': 'Honza Král',
#    'title': 'From __icontains to search'},
#   'hamly': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Виктор Коцеруба, Имхонет',
#    'title': 'Выжимаем максимум из шаблонизатора'},
#   'jetbrains': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Андрей Власовских, JetBrains',
#    'title': 'Многозадачность в Python и других языках'},
#   'kivy': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Дмитрий Овчинников, Wargaming.net',
#    'title': 'Разработка мобильных приложений на Python'},
#   'lightning-talks-1': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': None,
#    'title': None},
#   'lightning-talks-2': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': None,
#    'title': None},
#   'memory': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Константин Лопухин, ЧТД',
#    'title': 'На что уходит память?'},
#   'open_source_advices': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': 'Андрей Светлов, LevelUp',
#    'title': 'Как не надо делать, чтобы ваш Open Source продукт стал пользоваться успехом'},
#   'pony_orm': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Алексей Малашкевич, Александр Козловский',
#    'title': 'Pony ORM - маппер нового поколения'},
#   'python3': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': 'Brian Curtin',
#    'title': 'Python 3 and the Road Ahead'},
#   'python_in_yandex': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': 'Александр Кошелев, Яндекс',
#    'title': 'Python-разработка в части Яндекс-вселенной'},
#   'python_pytest': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Денис Чернилевский, Яндекс',
#    'title': 'Понятные и расширяемые отчеты для Python+PyTest из коробки'},
#   'scrapinghub': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Михаил Коробов',
#    'title': 'Извлечение информации из веб-страниц'},
#   'soa': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': 'Виталий Глибин, HeadHunter.ru',
#    'title': 'Использование сервис-ориентированной архитектуры (SOA) для построения сложных веб проектов'},
#   'the-sorry-state-of-ssl': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Hynek Schlawack',
#    'title': 'The Sorry State of SSL'},
#   'underscore': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Александр Щепановский',
#    'title': 'Почему Python нужен (был) свой underscore'},
#   'workshop': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': 'Роман Иманкулов, Михаил Коробов, Антон Патрушев',
#    'title': 'Мастер-класс Python против вандалов. Анализ данных на практике'},
#   'workshop2': {'datetime': datetime.datetime(2013, 6, 3, 0, 0),
#    'speaker': 'Алексей Малашкевич, Александр Козловский',
#    'title': 'Мастер-класс: пишем интерактивное приложение для обмена фотографиями, используя Pony ORM.'},
#   'writing-secure-apis': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Armin Ronacher',
#    'title': 'Writing Secure APIs'},
#   'ya_tank': {'datetime': datetime.datetime(2014, 6, 2, 0, 0),
#    'speaker': 'Алексей Лавренюк, Яндекс',
#    'title': 'Нагрузочное тестирование с помощью Яндекс.Танка'}},
#  24)

# %%
set(t['slug'].lower() for t in talks)
# Out:
# {'asyncio',
#  'autoscaling-on-the-cloud',
#  'bdd_in_python',
#  'data_analysis',
#  'explore-your-data',
#  'hamly',
#  'jetbrains',
#  'kivy',
#  'memory',
#  'open_source_advices',
#  'pony_orm',
#  'python3',
#  'python_in_yandex',
#  'python_pytest',
#  'registrer',
#  'scrapinghub',
#  'soa',
#  'the-sorry-state-of-ssl',
#  'underscore',
#  'workshop',
#  'workshop2',
#  'writing-secure-apis',
#  'ya_tank'}

# %%
import re
from urllib.parse import urlparse

for t in talks:
    try:
        t['datetime'] = schedule[t['slug'].lower()]['datetime'].isoformat()
        t['speaker'] = schedule[t['slug'].lower()]['speaker']
        t['title'] = schedule[t['slug'].lower()]['title']
    except:
        pass

# %%
import json

with open('/home/paul/src/pyvideodata/pycon-ru-2014/talks.json', 'w') as f:
    json.dump(talks, f, **{
        'indent': 2,
        'separators': (',', ': '),
        'sort_keys': True,
    })

# %%
playlist_urls = '''https://www.youtube.com/watch?v=Ooi5ECECwkA
https://www.youtube.com/watch?v=6CeXt62Dt2A
https://www.youtube.com/watch?v=cvU6vQFugsc
https://www.youtube.com/watch?v=rhMGkTQc0wU
https://www.youtube.com/watch?v=FAK03HHsPWU
https://www.youtube.com/watch?v=LGhMQ8YoEiY
https://www.youtube.com/watch?v=zPrEgGAXdhI
https://www.youtube.com/watch?v=7Ix9aI7apmQ
https://www.youtube.com/watch?v=jRDT7kslD8A
https://www.youtube.com/watch?v=hERb4be-h0w
https://www.youtube.com/watch?v=DTm4bHPZ7Vc
https://www.youtube.com/watch?v=b_rGwaryDmI
https://www.youtube.com/watch?v=vlBzrgfGNbQ
https://www.youtube.com/watch?v=toaB4dbr0D0
https://www.youtube.com/watch?v=n4nfjM1ecgw
https://www.youtube.com/watch?v=yybXi8EsfHo
https://www.youtube.com/watch?v=P0QGFuq_M1g
https://www.youtube.com/watch?v=11hGwtHF3SU
https://www.youtube.com/watch?v=-tsHmOVlRio
https://www.youtube.com/watch?v=La75xaG6HO0
https://www.youtube.com/watch?v=TAowGjrW2Fo
https://www.youtube.com/watch?v=vKkHLNHpFUI
https://www.youtube.com/watch?v=f6-C1ycmYho
https://www.youtube.com/watch?v=-UMzPDr87JU
https://www.youtube.com/watch?v=q7AtGVx3DMM'''.splitlines()

github_urls = '''https://www.youtube.com/watch?v=rhMGkTQc0wU
https://www.youtube.com/watch?v=zPrEgGAXdhI
https://www.youtube.com/watch?v=-tsHmOVlRio
https://www.youtube.com/watch?v=toaB4dbr0D0
https://www.youtube.com/watch?v=q7AtGVx3DMM
https://www.youtube.com/watch?v=vlBzrgfGNbQ
https://www.youtube.com/watch?v=yybXi8EsfHo
https://www.youtube.com/watch?v=f6-C1ycmYho
https://www.youtube.com/watch?v=TAowGjrW2Fo
https://www.youtube.com/watch?v=jRDT7kslD8A
https://www.youtube.com/watch?v=7Ix9aI7apmQ
https://www.youtube.com/watch?v=-UMzPDr87JU
https://www.youtube.com/watch?v=FAK03HHsPWU
https://www.youtube.com/watch?v=11hGwtHF3SU
https://www.youtube.com/watch?v=n4nfjM1ecgw
https://www.youtube.com/watch?v=cvU6vQFugsc
https://www.youtube.com/watch?v=LGhMQ8YoEiY
https://www.youtube.com/watch?v=P0QGFuq_M1g
https://www.youtube.com/watch?v=vKkHLNHpFUI
https://www.youtube.com/watch?v=6CeXt62Dt2A
https://www.youtube.com/watch?v=La75xaG6HO0
https://www.youtube.com/watch?v=Ooi5ECECwkA'''.splitlines()

# %%
# in YouTube playlist but not in the website archive
set(playlist_urls) - set(github_urls)
# Out:
# {'https://www.youtube.com/watch?v=DTm4bHPZ7Vc',
#  'https://www.youtube.com/watch?v=b_rGwaryDmI',
#  'https://www.youtube.com/watch?v=hERb4be-h0w'}

# %%
# in the website archive but no in YouTube playlist
set(github_urls) - set(playlist_urls)
# Out:
# set()

# %%
import pprint

pprint.pprint(talks)
# Out:
# [{'datetime': '2014-06-02T00:00:00',
#   'en': {'description': 'An introduction into writing secure APIs with '
#                         'Python.  This covers both integral API design for '
#                         'internal APIs as well as remotely exposed APIs; both '
#                         'high level basics such as use of protocols (SSL and '
#                         'OAuth) as well as how to structure internal security '
#                         'contexts.  On top of that it shows how to take '
#                         'advantage of Python features to make writing secure '
#                         'code easier.\n',
#          'speaker': 'Armin Ronacher',
#          'speaker_desc': '[Flask](http://flask.pocoo.org/) and '
#                          '[Jinja2](http://jinja.pocoo.org/) creator, [Pocoo '
#                          'Team](http://www.pocoo.org/) founder, '
#                          '[PSF](https://www.python.org/psf) member, developer '
#                          'at [Splash Damage](http://www.splashdamage.com/)',
#          'speaker_slug': 'armin-ronacher',
#          'title': 'Writing Secure APIs'},
#   'media': 'https://www.youtube.com/embed/-D3ckFhR-yE',
#   'ru': {'description': 'An introduction into writing secure APIs with '
#                         'Python.  This covers both integral API design for '
#                         'internal APIs as well as remotely exposed APIs; both '
#                         'high level basics such as use of protocols (SSL and '
#                         'OAuth) as well as how to structure internal security '
#                         'contexts.  On top of that it shows how to take '
#                         'advantage of Python features to make writing secure '
#                         'code easier.\n',
#          'speaker': 'Armin Ronacher',
#          'speaker_desc': '[Flask](http://flask.pocoo.org/) and '
#                          '[Jinja2](http://jinja.pocoo.org/) creator, [Pocoo '
#                          'Team](http://www.pocoo.org/) founder, '
#                          '[PSF](https://www.python.org/psf) member, developer '
#                          'at [Splash Damage](http://www.splashdamage.com/)',
#          'speaker_slug': 'armin-ronacher',
#          'title': 'Writing Secure APIs'},
#   'slug': 'writing-secure-apis',
#   'speaker': 'Armin Ronacher',
#   'title': 'Writing Secure APIs',
#   'youtube_url': 'https://www.youtube.com/watch?v=-D3ckFhR-yE'},
#  {'datetime': '2014-06-02T00:00:00',
#   'en': {'description': 'Those web pages with shiny lock icons boasting that '
#                         'your data is safe because of “256 bit encryption”? '
#                         'They are lying. In times of mass surveillance and '
#                         'commercialized Internet crime you should know why '
#                         'that’s the case. This talk will give you an overview '
#                         'that will help you to assess your personal security '
#                         'more realistically and to make your applications as '
#                         'secure as possible against all odds.  \n'
#                         'The rule of thumb for people without degrees in '
#                         'cryptography on securing data on the Internet is “GPG '
#                         'for data at rest. TLS for data in motion”. And it’s '
#                         'actually a very good rule everyone should follow.  \n'
#                         'The only kicker though is that configuring (and '
#                         'using!) TLS properly is not as simple as it sounds '
#                         'and if you’re not diligent as a user, developer, and '
#                         'ops engineer, you can easily compromise your data’s '
#                         'security despite best effort of everyone else.  \n'
#                         'This talk will be multifaceted; you will learn:  \n'
#                         '- how SSL and TLS roughly work and why their state is '
#                         'sorry,  \n'
#                         '- server- and client-side duties for best possible '
#                         'security,  \n'
#                         '- what alternatives you have for using TLS in '
#                         'Python,  \n'
#                         '- things to keep in mind when configuring servers,  \n'
#                         '- and what perils outside your control still can trip '
#                         'you up.  \n'
#                         'In other words, the leitmotif is to show you the most '
#                         'common traps you should know about when using and '
#                         'deploying applications relying on TLS for transport '
#                         'layer security and how to avoid them.',
#          'speaker': 'Hynek Schlawack',
#          'speaker_desc': '[CPython](https://www.python.org/) & '
#                          '[Twisted](https://twistedmatrix.com/) core dev, '
#                          '[PSF](https://www.python.org/psf) member, head of '
#                          'infrastructure and board representative at '
#                          '[Variomedia](http://www.variomedia.de/)',
#          'speaker_slug': 'hynek-schlawack',
#          'title': 'The Sorry State of SSL'},
#   'media': 'https://www.youtube.com/embed/1gnaduQIuWA',
#   'ru': {'description': 'Those web pages with shiny lock icons boasting that '
#                         'your data is safe because of “256 bit encryption”? '
#                         'They are lying. In times of mass surveillance and '
#                         'commercialized Internet crime you should know why '
#                         'that’s the case. This talk will give you an overview '
#                         'that will help you to assess your personal security '
#                         'more realistically and to make your applications as '
#                         'secure as possible against all odds.  \n'
#                         'The rule of thumb for people without degrees in '
#                         'cryptography on securing data on the Internet is “GPG '
#                         'for data at rest. TLS for data in motion”. And it’s '
#                         'actually a very good rule everyone should follow.  \n'
#                         'The only kicker though is that configuring (and '
#                         'using!) TLS properly is not as simple as it sounds '
#                         'and if you’re not diligent as a user, developer, and '
#                         'ops engineer, you can easily compromise your data’s '
#                         'security despite best effort of everyone else.  \n'
#                         'This talk will be multifaceted; you will learn:  \n'
#                         '- how SSL and TLS roughly work and why their state is '
#                         'sorry,  \n'
#                         '- server- and client-side duties for best possible '
#                         'security,  \n'
#                         '- what alternatives you have for using TLS in '
#                         'Python,  \n'
#                         '- things to keep in mind when configuring servers,  \n'
#                         '- and what perils outside your control still can trip '
#                         'you up.  \n'
#                         'In other words, the leitmotif is to show you the most '
#                         'common traps you should know about when using and '
#                         'deploying applications relying on TLS for transport '
#                         'layer security and how to avoid them.',
#          'speaker': 'Hynek Schlawack',
#          'speaker_desc': '[CPython](https://www.python.org/) & '
#                          '[Twisted](https://twistedmatrix.com/) core dev, '
#                          '[PSF](https://www.python.org/psf) member, head of '
#                          'infrastructure and board representative at '
#                          '[Variomedia](http://www.variomedia.de/)',
#          'speaker_slug': 'hynek-schlawack',
#          'title': 'The Sorry State of SSL'},
#   'slug': 'the-sorry-state-of-ssl',
#   'speaker': 'Hynek Schlawack',
#   'title': 'The Sorry State of SSL',
#   'youtube_url': 'https://www.youtube.com/watch?v=1gnaduQIuWA'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/KbbbOCay38A',
#   'ru': {'description': 'Мобильная разработка на Python  \n'
#                         'Python для мобильных девайсов  \n'
#                         'Обзор похожих продуктов  \n'
#                         'Kivy — птица или фрукт?  \n'
#                         'Один код на разных платформах (Не Java)  \n'
#                         'Знакомимся с фреймворком  \n'
#                         'Как это работает?  \n'
#                         'Разметка UI на "почти" python  \n'
#                         "Сборка приложения с помощью Buildozer'а   \n",
#          'speaker': '**Дмитрий Овчинников**,  Wargaming.net \n',
#          'title': 'Разработка мобильных приложений на Python'},
#   'slug': 'kivy',
#   'speaker': 'Дмитрий Овчинников, Wargaming.net',
#   'title': 'Разработка мобильных приложений на Python',
#   'youtube_url': 'https://www.youtube.com/watch?v=KbbbOCay38A'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/hj-8l3AejNc',
#   'ru': {'description': 'Рассказ о том, как извлеченть данные из веб-страниц с '
#                         'использованием Python:  \n'
#                         '- как извлечь информацию из одного-единственного '
#                         'сайта;  \n'
#                         '- как сделать это без написания xpath, css селекторов '
#                         'и т.д.;  \n'
#                         '- как извлекать информацию, если структура сайта '
#                         'неизвестна заранее;  \n'
#                         '- когда стоит применять методы машинного обучения и '
#                         'как это делать;  \n'
#                         '- какие инструменты доступны на Python.  \n'
#                         'Доклад рассчитан на тех людей, кому хочется извлекать '
#                         'какую-то структурированную информацию из веб-страниц '
#                         'или из текста. Это могут быть задачи информационного '
#                         'поиска, анализа данных, составления каталогов, '
#                         'получения информации для каких-то исследований и '
#                         'т.д.  \n'
#                         'Какую пользу слушатели получат?   \n'
#                         '"Ручной" разбор веб-страниц через XPath / CSS '
#                         'селекторы - не единственный инструмент. Возможно, '
#                         'некоторые задачи, которые раньше казались очень '
#                         'сложными, покажутся вполне решаемыми.  \n',
#          'speaker': '**Михаил Коробов**, работает в ScrapingHub, входит в NLTK '
#                     'Team, коммитер в Scrapy, автор pymorphy2 и других '
#                     'open-source проектов.\n',
#          'title': 'Извлечение информации из веб-страниц'},
#   'slug': 'scrapinghub',
#   'speaker': 'Михаил Коробов',
#   'title': 'Извлечение информации из веб-страниц',
#   'youtube_url': 'https://www.youtube.com/watch?v=hj-8l3AejNc'},
#  {'datetime': '2013-06-03T00:00:00',
#   'media': 'https://www.youtube.com/embed/LTwTKUrvR94',
#   'ru': {'description': 'Вы запилили нечто очень полезное и даже выложили на '
#                         'github.Только этим никто не пользуется.  \n'
#                         'Разбираем проблемы, ищем решение.  \n'
#                         'Чтобы на поделку обратили внимание нужны:    \n'
#                         '-- Социальность и публичность  \n'
#                         '-- Документация  \n'
#                         '-- Тесты  \n'
#                         '-- Система контроля версий (версии, релизы) и '
#                         'багтрекер  \n'
#                         '-- setup.py, pypi и readthedocs    \n'
#                         '\n'
#                         'И, наконец, Программный Код.    \n'
#                         '-- Ясность интерфейсов и абстракций  \n'
#                         '-- Четкое разделение на Public API и детали '
#                         'реализации (напишешь пером - не вырубишь и '
#                         'топором)  \n'
#                         '-- Docstrings  \n'
#                         '-- Выбор хороших имен классов-методов  \n'
#                         '-- Естественная полнота Public API  \n'
#                         '-- Следование устоявшимся соглашениям  \n'
#                         '-- магические методы  \n'
#                         '-- collections.abc  \n'
#                         '-- предметная область или почему нельзя перегружать '
#                         '"+" для матрицы.   \n'
#                         '\n'
#                         'Каждый пункт снабжен примерами и антипримерами.\n',
#          'speaker': '**Андрей Светлов**, Python Core Developer или просто '
#                     'committer в [hg.python.org](http://hg.python.org/). В '
#                     'текущее время архитектор в '
#                     '[LevelUp](http://levelupers.com/)\n',
#          'title': 'Как не надо делать, чтобы ваш Open Source продукт стал '
#                   'пользоваться успехом'},
#   'slug': 'open_source_advices',
#   'speaker': 'Андрей Светлов, LevelUp',
#   'title': 'Как не надо делать, чтобы ваш Open Source продукт стал '
#            'пользоваться успехом',
#   'youtube_url': 'https://www.youtube.com/watch?v=LTwTKUrvR94'},
#  {'datetime': '2013-06-03T00:00:00',
#   'media': 'https://www.youtube.com/embed/ZwnBbPzbAEM',
#   'ru': {'description': 'Расскажу о том, что такое SOA, какие проблемы решает, '
#                         'а какие добавляет.\n'
#                         'Как мы готовим SOA в самом высоконагруженном '
#                         'job-портале рунета.\n'
#                         'Frontik и tortik - настоящее и будущее наших '
#                         'frontend-фреймворков на базе Python Tornado.\n'
#                         'Подробный рассказ о tortik - архитектура, '
#                         'возможности, тонкости.\n'
#                         'Покажу примеры использования, удобство отладки и '
#                         'профилирования как в development окружении, так и в '
#                         'production.\n',
#          'speaker': '**Виталий Глибин**, ведущий frontend разработчик в '
#                     '[HeadHunter](http://hh.ru), преподаватель  [Школы '
#                     'программистов HeadHunter](http://school.hh.ru) \n',
#          'title': 'Использование сервис-ориентированной архитектуры (SOA) для '
#                   'построения сложных веб проектов'},
#   'slug': 'soa',
#   'speaker': 'Виталий Глибин, HeadHunter.ru',
#   'title': 'Использование сервис-ориентированной архитектуры (SOA) для '
#            'построения сложных веб проектов',
#   'youtube_url': 'https://www.youtube.com/watch?v=ZwnBbPzbAEM'},
#  {'datetime': '2013-06-03T00:00:00',
#   'media': 'https://www.youtube.com/embed/dr9waR1tmgU',
#   'ru': {'description': 'В докладе будет раскрыта суть behavior-driven подхода '
#                         'к разработке ПО: история возникновения, основы '
#                         'методологии, примеры сценариев, отличия от '
#                         'существующих подходов, имеющиеся инструменты для '
#                         'применения в Python-проектах. А так же опыт его '
#                         'внедрения, возникавшие проблемы и решения.\n',
#          'speaker': '**Кирилл Борисов**, архитектор в БАРС Груп\n',
#          'title': 'Behavior Driven Development in Python'},
#   'slug': 'bdd_in_python',
#   'speaker': 'Кирилл Борисов, БАРС Груп',
#   'title': 'Behavior Driven Development in Python',
#   'youtube_url': 'https://www.youtube.com/watch?v=dr9waR1tmgU'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/rwd6m6npTZo',
#   'ru': {'description': 'В Python существует долгая традиция заимствования '
#                         'механизмов многозадачности из других языков.\n'
#                         'Вначале это были C и окружение POSIX, затем Java и '
#                         'C#. \n'
#                         'В докладе будет рассказано о том, как устроены и чего '
#                         'позволяют достичь механизмымногозадачности в Python, '
#                         'включая новые механизмы Python 3 concurrent.futures и '
#                         'asyncio.\n'
#                         'Мы рассмотрим какие механизмы подходят для задач, '
#                         'ограниченных по CPU и IO, в частности, какими '
#                         'преимуществами и недостатками обладают механизмы в '
#                         'Python.\n'
#                         'Наконец мы поговорим о том, какие подходы к '
#                         'многозадачности есть в языках Erlang и Go и насколько '
#                         'они применимы к Python.\n',
#          'speaker': '**Андрей Власовских**, разработчик IDE PyCharm в '
#                     'JetBrains, автор библиотек funcparserlib и iterpipes.\n',
#          'title': 'Многозадачность в Python и других языках'},
#   'slug': 'jetbrains',
#   'speaker': 'Андрей Власовских, JetBrains',
#   'title': 'Многозадачность в Python и других языках',
#   'youtube_url': 'https://www.youtube.com/watch?v=rwd6m6npTZo'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/Pk_vJ5H2DkY',
#   'ru': {'description': 'Мы поговорим о нагрузочном тестировании, open source '
#                         'инструменте Яндекс.Танк и о том, как заточить его для '
#                         'своих нужд и автоматизировать процесс тестирования с '
#                         'помощью Python.\n'
#                         'Доклад рассчитан на разработчиков и системных '
#                         'администраторов, которые предвидят или уже '
#                         'столкнулись с проблемами производительности и хотят '
#                         'познакомиться с процессом нагрузочного тестирования и '
#                         'инструментами.\n'
#                         'Люди узнают о процессе нагрузочного тестирования, о '
#                         'том, подходит ли Яндекс.Танк для выявления проблем '
#                         'производительности их сервисов и о том, как расширить '
#                         'Яндекс.Танк для автоматизации и решения своих '
#                         'специфических задач.\n',
#          'speaker': '**Алексей Лавренюк**, Яндекс. Занимается нагрузочным '
#                     'тестированием в отделе рекламных технологий. Один из '
#                     'участников open source проекта Яндекс.Танк.\n',
#          'title': 'Нагрузочное тестирование с помощью Яндекс.Танка'},
#   'slug': 'ya_tank',
#   'speaker': 'Алексей Лавренюк, Яндекс',
#   'title': 'Нагрузочное тестирование с помощью Яндекс.Танка',
#   'youtube_url': 'https://www.youtube.com/watch?v=Pk_vJ5H2DkY'},
#  {'datetime': '2013-06-03T00:00:00',
#   'en': {'description': "Learn where we're at with Python 3, where we're "
#                         "going, and how we'll get there.  \n"
#                         'The talk will include a recap of Python 3 discussions '
#                         'from the Python Language Summit as well as some of '
#                         'the ideas that came out of it.\n'
#                         "There's a lot of talk around the community about what "
#                         'to do, and there are some plans to move forward. Find '
#                         'out what the future holds for Python 2.7 and the rest '
#                         'of the Python 3 series.  \n'
#                         "You'll also find out about some great resources to "
#                         'help your own projects along the way.\n',
#          'speaker': 'Brian Curtin',
#          'speaker_desc': 'director of the [PSF](https://www.python.org/psf), '
#                          'software engineer at '
#                          '[Rackspace](http://www.rackspace.com/)',
#          'speaker_slug': 'brian-curtin',
#          'title': 'Python 3 and the Road Ahead'},
#   'media': 'https://www.youtube.com/embed/Y4wahwOmkWs',
#   'ru': {'description': "Learn where we're at with Python 3, where we're "
#                         "going, and how we'll get there.  \n"
#                         'The talk will include a recap of Python 3 discussions '
#                         'from the Python Language Summit as well as some of '
#                         'the ideas that came out of it.\n'
#                         "There's a lot of talk around the community about what "
#                         'to do, and there are some plans to move forward. Find '
#                         'out what the future holds for Python 2.7 and the rest '
#                         'of the Python 3 series.  \n'
#                         "You'll also find out about some great resources to "
#                         'help your own projects along the way.\n',
#          'speaker': 'Brian Curtin',
#          'speaker_desc': 'director of the [PSF](https://www.python.org/psf), '
#                          'software engineer at '
#                          '[Rackspace](http://www.rackspace.com/)',
#          'speaker_slug': 'brian-curtin',
#          'title': 'Python 3 and the Road Ahead'},
#   'slug': 'python3',
#   'speaker': 'Brian Curtin',
#   'title': 'Python 3 and the Road Ahead',
#   'youtube_url': 'https://www.youtube.com/watch?v=Y4wahwOmkWs'},
#  {'datetime': '2013-06-03T00:00:00',
#   'ru': {'description': 'Мастер-класс продолжает и расширяет доклад "python '
#                         'для анализа данных".\n'
#                         'Здесь под чутким руководством инструкторов все '
#                         'желающие смогут воспитать собственный алгоритм, '
#                         'несущий добро.\n'
#                         'Любой участник мастер-класса сможет попробовать '
#                         'обучить python автоматическому распознаванию '
#                         'вандальных правок в википедии, а благодаря '
#                         'сотрудничеству с проектом kaggle.com, сравнить его '
#                         'эффективность с результатами других участников, и '
#                         'побороться за звание "лучший дата-аналитик '
#                         'pycon.ru".  \n'
#                         '  \n'
#                         '    \n'
#                         '      \n'
#                         '        \n'
#                         '          \n'
#                         '          \n',
#          'speaker': '**Роман Иманкулов**, **Михаил Коробов**, **Антон '
#                     'Патрушев**\n',
#          'title': 'Мастер-класс Python против вандалов. Анализ данных на '
#                   'практике'},
#   'slug': 'workshop',
#   'speaker': 'Роман Иманкулов, Михаил Коробов, Антон Патрушев',
#   'title': 'Мастер-класс Python против вандалов. Анализ данных на практике'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/HkjoE54i-E8',
#   'ru': {'description': 'Pony ORM - маппер, который позволяет работать с базой '
#                         'данных с помощью генераторных выражений языка '
#                         'Питон.  \n'
#                         'С помощью такого подхода Pony позволяет формулировать '
#                         'очень компактные и понятные запросы, которые '
#                         'автоматически транслируются в оптимизированный '
#                         'SQL.   \n'
#                         'Pony обладает графическим редактором ER диаграмм - '
#                         'удобным инструментом для создания и редактирования '
#                         'модели данных.  \n'
#                         'В докладе разработчики Pony ORM расскажут про процесс '
#                         'перевода объектно-ориентированного запроса в запрос '
#                         'на языке SQL, о том, какие оптимизации Pony применяет '
#                         'на каждом этапе обработки запроса, какие сложности '
#                         'стояли при разработке высокопроизводительного ORM и '
#                         'как Pony ORM облегчает и ускоряет разработку '
#                         'приложений.   \n'
#                         '\n'
#                         'На второй день всех заинтересовавшихся докладом ждет '
#                         'практический мастер-класс, в котором Pony можно будет '
#                         'попробовать использовать самому.  \n'
#                         '\n'
#                         '  \n'
#                         '    \n'
#                         '      \n'
#                         '        \n'
#                         '        \n',
#          'speaker': '**Алексей Малашкевич, Александр Козловский**, \n',
#          'title': 'Pony ORM - маппер нового поколения'},
#   'slug': 'pony_orm',
#   'speaker': 'Алексей Малашкевич, Александр Козловский',
#   'title': 'Pony ORM - маппер нового поколения',
#   'youtube_url': 'https://www.youtube.com/watch?v=HkjoE54i-E8'},
#  {'slug': 'registrer'},
#  {'datetime': '2013-06-03T00:00:00',
#   'media': 'https://www.youtube.com/embed/6_bhf2kHUvs',
#   'ru': {'description': 'В Python 3.4 вошла стандартная библиотека asyncio для '
#                         'асинхронного сетевого программирования. \n'
#                         'Она строилась с учетом опыта использования Twisted и '
#                         'Tornado, авторы этих библиотек принимали участие в '
#                         'обсуждениях и выработке концепций.\n'
#                         'В результате получилось очень неплохо.\n'
#                         'Тем не менее пока что мало информации по правильному '
#                         'использованию и написанию кода для asyncio -- по сути '
#                         'есть только документация и несколько постов в '
#                         'блогах.  \n'
#                         'Лекция включает  \n'
#                         'Обзор базовых примитивов и принципов построения '
#                         'пользовательского кода.  \n'
#                         'Какие части библиотеки предназначены для "простого '
#                         'программиста"  \n'
#                         'Что не нужно использовать, т.к. некоторые API слишком '
#                         'низкоуровневые и нужны только создания "человеческих" '
#                         'библиотек.\n',
#          'speaker': '**Андрей Светлов**, Python Core Developer или просто '
#                     'committer в [hg.python.org](http://hg.python.org/). В '
#                     'текущее время архитектор в '
#                     '[LevelUp](http://levelupers.com/)\n',
#          'title': 'Как писать для asyncio. Советы от разработчика библиотеки.'},
#   'slug': 'asyncio',
#   'speaker': 'Андрей Светлов, LevelUp',
#   'title': 'Как писать для asyncio. Советы от разработчика библиотеки.',
#   'youtube_url': 'https://www.youtube.com/watch?v=6_bhf2kHUvs'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/GXovl9zG1lA',
#   'ru': {'description': 'Основное, чему в выступлении уделяется внимание – '
#                         'возможность просчета многих вещей, порождаемых '
#                         'метапрограммированием, заранее.\n'
#                         'Пример для наглядной демонстрации - '
#                         '[hamly](https://github.com/barbuza/hamly), '
#                         'шаблонизатор, в несколько раз обгоняющий jinja2 '
#                         '(который обычно считают самым быстрым из доступных на '
#                         'python).\n'
#                         'Будут рассмотрены несколько типовых кейсов применения '
#                         'оптимизаций и общая логика поиска новых.\n',
#          'speaker': '**Виктор Коцеруба**, Имхонет\n',
#          'title': 'Выжимаем максимум из шаблонизатора'},
#   'slug': 'hamly',
#   'speaker': 'Виктор Коцеруба, Имхонет',
#   'title': 'Выжимаем максимум из шаблонизатора',
#   'youtube_url': 'https://www.youtube.com/watch?v=GXovl9zG1lA'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/d5SreR6dGnE',
#   'ru': {'description': 'В любом проекте, в котором есть автоматизированное '
#                         'тестирование, люди сталкиваются с проблемой '
#                         'построения удобных, понятных, легко расширяемых и '
#                         'красивых отчетов для тестов.\n'
#                         'При этом часто команды не используют стандартный '
#                         'xUnit формат и его представление по-умолчанию в '
#                         'системах CI, например в Jenkins, а пишут свой формат '
#                         'отчетов. \n'
#                         'Проанализировав требования некоторого числа команд '
#                         'тестирования, мы внутри Яндекса разработали '
#                         'инструмент построения отчетов Allure Framework, '
#                         'который сейчас является open source проектом.\n'
#                         'Он может применяться в разных системах тестирования и '
#                         'языках программирования, с помощью механизма '
#                         'адапторов.\n'
#                         'В этом докладе я на примерах расскажу об основных '
#                         'фичах этого инструмента и о том, как из коробки '
#                         'внедрить Allure отчеты с помощью готового python '
#                         'адаптора, если вы пользуетесь Python + PyTest.\n',
#          'speaker': '**Денис Чернилевский**, Руководитель группы тестирования '
#                     'рекламных технологий в Яндексе\n',
#          'title': 'Понятные и расширяемые отчеты для Python+PyTest из коробки'},
#   'slug': 'python_pytest',
#   'speaker': 'Денис Чернилевский, Яндекс',
#   'title': 'Понятные и расширяемые отчеты для Python+PyTest из коробки',
#   'youtube_url': 'https://www.youtube.com/watch?v=d5SreR6dGnE'},
#  {'datetime': '2013-06-03T00:00:00',
#   'ru': {'description': 'В этом мастер-классе можно будет применить знания, '
#                         'полученные от прослушивания лекции об '
#                         'объектно-реляционном маппере Pony ORM и испробовать '
#                         'маппер на практике при построении интерактивного '
#                         'веб-приложения для обмена фотографиями.  \n'
#                         '\n'
#                         '\n'
#                         '  \n'
#                         ' \n'
#                         '  \n'
#                         ' \n'
#                         '  \n'
#                         '   \n'
#                         '     \n'
#                         '       \n'
#                         '         \n'
#                         '         \n'
#                         '    \n'
#                         '      \n'
#                         '        \n'
#                         '        \n',
#          'speaker': '**Алексей Малашкевич, Александр Козловский**, \n',
#          'title': 'Мастер-класс: пишем интерактивное приложение для обмена '
#                   'фотографиями используя Pony ORM.'},
#   'slug': 'workshop2',
#   'speaker': 'Алексей Малашкевич, Александр Козловский',
#   'title': 'Мастер-класс: пишем интерактивное приложение для обмена '
#            'фотографиями, используя Pony ORM.'},
#  {'datetime': '2014-06-02T00:00:00',
#   'en': {'description': 'Horizontal scaling on the Cloud is the way to adapt '
#                         'resources to load of systems. The Cloud allows users '
#                         'to scale virtually indefinitely, or enough for their '
#                         'needs.  \n'
#                         'This way the number of servers follows trend of '
#                         'requests, and TCO (Total Cost of Owneship) of IT '
#                         'infrastructure can be minimised. Nonetheless '
#                         'companies can avoid dealing with capacity planning '
#                         'and pre-provisioning issues.  \n'
#                         'This talk will show how to use Python and '
#                         'Rackspace/OpenStack API and SDK to implement an '
#                         'event-based scaling solution (software released under '
#                         'the open-source Apache License).  \n'
#                         'The outline of this talk will be:  \n'
#                         '- Auto scale (Why, What, When, How);  \n'
#                         '- Leveraging Cloud Monitoring to trigger Auto Scale '
#                         'policies;  \n'
#                         '- Configuration management system (Ansible and '
#                         'playbooks) to deploy applications;  \n'
#                         '- "Go Live!", "Update" and "Rollback" patterns.  \n'
#                         'Outcome: Knowledge of scaling techniques, Cloud '
#                         'patterns and issues.',
#          'speaker': 'Simone Soldateschi',
#          'speaker_desc': 'developer support engineer at '
#                          '[Rackspace](http://www.rackspace.com/)',
#          'speaker_slug': 'simone-soldateschi',
#          'title': 'Auto scaling on the Cloud the right way'},
#   'media': 'https://www.youtube.com/embed/KPk0-xlwyxc',
#   'ru': {'description': 'Horizontal scaling on the Cloud is the way to adapt '
#                         'resources to load of systems. The Cloud allows users '
#                         'to scale virtually indefinitely, or enough for their '
#                         'needs.  \n'
#                         'This way the number of servers follows trend of '
#                         'requests, and TCO (Total Cost of Owneship) of IT '
#                         'infrastructure can be minimised. Nonetheless '
#                         'companies can avoid dealing with capacity planning '
#                         'and pre-provisioning issues.  \n'
#                         'This talk will show how to use Python and '
#                         'Rackspace/OpenStack API and SDK to implement an '
#                         'event-based scaling solution (software released under '
#                         'the open-source Apache License).  \n'
#                         'The outline of this talk will be:  \n'
#                         '- Auto scale (Why, What, When, How);  \n'
#                         '- Leveraging Cloud Monitoring to trigger Auto Scale '
#                         'policies;  \n'
#                         '- Configuration management system (Ansible and '
#                         'playbooks) to deploy applications;  \n'
#                         '- "Go Live!", "Update" and "Rollback" patterns.  \n'
#                         'Outcome: Knowledge of scaling techniques, Cloud '
#                         'patterns and issues.',
#          'speaker': 'Simone Soldateschi',
#          'speaker_desc': 'developer support engineer at '
#                          '[Rackspace](http://www.rackspace.com/)',
#          'speaker_slug': 'simone-soldateschi',
#          'title': 'Auto scaling on the Cloud the right way'},
#   'slug': 'autoscaling-on-the-cloud',
#   'speaker': 'Simone Soldateschi',
#   'title': 'Auto scaling on the Cloud the right way',
#   'youtube_url': 'https://www.youtube.com/watch?v=KPk0-xlwyxc'},
#  {'datetime': '2013-06-03T00:00:00',
#   'en': {'description': 'Good search experience is about more than just '
#                         'finding matching substring, \n'
#                         'and in this talk I would like to present how it '
#                         'actually works. We will build \n'
#                         'out a model of a search engine and analyze the result '
#                         '- what sort of functionality \n'
#                         'and characteristics will the resulting engine have? '
#                         'What features can we implement \n'
#                         'on top of it?  \n'
#                         '\n'
#                         'Most of the talk will be generic but there will be '
#                         'some concrete examples from \n'
#                         'Elasticsearch. At the end of the talk there will be '
#                         'time for questions regarding \n'
#                         'anything search related.',
#          'speaker': 'Honza Král',
#          'speaker_desc': '[Django](https://www.djangoproject.com/) developer '
#                          'and enthusiast, python developer at '
#                          '[Elasticsearch](http://www.elasticsearch.org/)',
#          'speaker_slug': 'honza-kral',
#          'title': 'From __icontains to search'},
#   'media': 'https://www.youtube.com/embed/WPDA2867mrE',
#   'ru': {'description': 'Good search experience is about more than just '
#                         'finding matching substring, \n'
#                         'and in this talk I would like to present how it '
#                         'actually works. We will build \n'
#                         'out a model of a search engine and analyze the result '
#                         '- what sort of functionality \n'
#                         'and characteristics will the resulting engine have? '
#                         'What features can we implement \n'
#                         'on top of it?  \n'
#                         '\n'
#                         'Most of the talk will be generic but there will be '
#                         'some concrete examples from \n'
#                         'Elasticsearch. At the end of the talk there will be '
#                         'time for questions regarding \n'
#                         'anything search related.',
#          'speaker': 'Honza Král',
#          'speaker_desc': '[Django](https://www.djangoproject.com/) developer '
#                          'and enthusiast, python developer at '
#                          '[Elasticsearch](http://www.elasticsearch.org/)',
#          'speaker_slug': 'honza-kral',
#          'title': 'From __icontains to search'},
#   'slug': 'explore-your-data',
#   'speaker': 'Honza Král',
#   'title': 'From __icontains to search',
#   'youtube_url': 'https://www.youtube.com/watch?v=WPDA2867mrE'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/e3oJ3I-i6Yg',
#   'ru': {'description': 'В последнее время анализ данных стал горячей темой.\n'
#                         'В  этом плане python разработчики по сравнению с '
#                         'остальными кастами программистов находятся в выгодном '
#                         'положении  —  в их распоряжении есть как несомненно '
#                         'прекрасный язык общего назначения, так и множество '
#                         'инструментов для научной обработки данных.\n'
#                         'О последних многие слышали, но мало кто знает, как '
#                         'этим пользоваться, и какую пользу они могут принести '
#                         'простым смертным.\n'
#                         'В докладе я познакомлю слушателей с основными '
#                         'инструментами для обработки данных: всемогущим '
#                         'ipython, библиотеками numpy, scipy, pandas и '
#                         'scikit-learn. В ходе ознакомления с ними на простом '
#                         'примере мы выясним, какую пользу для себя начинающий '
#                         'python аналитик может извлечь прямо сейчас.\n'
#                         'Доклад расчитан как на начинающих, так и на опытных '
#                         'разработчиков на python, которые, тем не менее, не '
#                         'имели серьезного опыта анализа данных, хотят '
#                         'попробовать, но не знают с чего начать.\n',
#          'speaker': '**Роман Иманкулов**, разработчик [Doist '
#                     'Inc](http://doist.io/)\n',
#          'title': 'Python для анализа данных.'},
#   'slug': 'data_analysis',
#   'speaker': 'Роман Иманкулов, Todoist',
#   'title': 'Python для анализа данных',
#   'youtube_url': 'https://www.youtube.com/watch?v=e3oJ3I-i6Yg'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/ZtnFcj0b5W4',
#   'ru': {'description': 'Такие библиотеки как funcy и underscore часто '
#                         'связывают с функциональным программированием, но '
#                         'настоящий их фокус - это практичность. \n'
#                         'Задача funcy - упростить манипулирование данными, '
#                         'коллекциями, функциями и даже потоком управления, а '
#                         'также абстрагировать часто встречащиеся полезные '
#                         'поведения. \n'
#                         'В своём докладе я приведу жизненные примеры '
#                         'использования всего этого, а также расскажу об идеях '
#                         'заложенных в и продвигаемых funcy.   \n'
#                         'Доклад рассчитан на всех, кто пишет на питоне, а '
#                         'также интересуется другими языками и парадигмами. '
#                         'Задача минимум - познакомить с библиотекой. \n'
#                         'Максимум - заставить по новому взглянуть на язык и на '
#                         'решаемые задачи. \n',
#          'speaker': '**Александр Щепановский**, автор '
#                     '[funcy](https://github.com/Suor/funcy), '
#                     '[cacheops](https://github.com/Suor/django-cacheops) и ещё '
#                     'нескольких библиотек.\n',
#          'title': 'Почему Python нужен (был) свой underscore'},
#   'slug': 'underscore',
#   'speaker': 'Александр Щепановский',
#   'title': 'Почему Python нужен (был) свой underscore',
#   'youtube_url': 'https://www.youtube.com/watch?v=ZtnFcj0b5W4'},
#  {'datetime': '2013-06-03T00:00:00',
#   'media': 'https://www.youtube.com/embed/Aly-OVFqg2o',
#   'ru': {'description': 'Что выбрать – системные пакеты или выкатка через git '
#                         'pull? Использовать virtualenv или нет? Так ли удобны '
#                         'PyPI и pip? Что делать, когда много библиотечного '
#                         'in-house кода? Как справиться с большим количеством '
#                         'сервисов в активной разработке?\n'
#                         'Я расскажу про то как в нашей части Яндекса мы '
#                         'разрабатываем сервисы на Python. Как мы пакетируем, '
#                         'тестируем и выкатываем проекты. Расскажу о проблемах '
#                         'и компромиссах. Поделюсь полезным опытом, который мы '
#                         'успели накопить за много лет.\n'
#                         'Мой доклад будет интересен всем, кто так или иначе '
#                         'занимается выкаткой на один или много серверов, '
#                         'больших и не очень проектов, сложных сервисов и '
#                         'вообще любого python-кода.\n',
#          'speaker': '**Александр Кошелев**, тимлид в Яндексе\n',
#          'title': 'Python-разработка в части Яндекс-вселенной'},
#   'slug': 'python_in_yandex',
#   'speaker': 'Александр Кошелев, Яндекс',
#   'title': 'Python-разработка в части Яндекс-вселенной',
#   'youtube_url': 'https://www.youtube.com/watch?v=Aly-OVFqg2o'},
#  {'datetime': '2014-06-02T00:00:00',
#   'media': 'https://www.youtube.com/embed/XwpUQX_8rmY',
#   'ru': {'description': 'Я хочу поговорить о проблеме потребления памяти '
#                         'приложений на Python - как понять что происходит, и '
#                         'что делать, когда оно больше чем нам хотелось бы.\n'
#                         'Сначала мы посмотрим, как вообще Python работает с '
#                         'памятью внутри, как он взаимодействует с ОС, может ли '
#                         'он отдавать память. \n'
#                         'Затем рассмотрим инструменты для анализа потребления '
#                         'памяти, и научимся интерпретировать их результат. \n'
#                         'Разберем типичные ошибки, которые приводят к '
#                         'излишнему потреблению памяти, рассмотрим некоторые '
#                         'приемы, которые могут позволить его уменьшить даже '
#                         'при отсутствии явных ляпов. \n'
#                         'В отличие от темы анализа производительности, на тему '
#                         'анализа потребления памяти на удивление мало '
#                         'материала, в основном только ответы на stackoverflow, '
#                         'поэтому хочется попробовать систематизировать то, что '
#                         'удалось узнать.\n',
#          'speaker': '**Константин Лопухин**, Технический директор в '
#                     '[ЧТД](http://chtd.ru/), помог возникновению '
#                     'psycopg2cffi\n',
#          'title': 'На что уходит память?'},
#   'slug': 'memory',
#   'speaker': 'Константин Лопухин, ЧТД',
#   'title': 'На что уходит память?',
#   'youtube_url': 'https://www.youtube.com/watch?v=XwpUQX_8rmY'}]
